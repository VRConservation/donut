# %% [markdown]
# # Interactive Maps
# Interactive maps to compare crown fire probability and potential impacts of fire on old-growth or mature forests and threatened and endangered species richness.

# %%
# pip install leafmap

# %%
# import dependencies
import leafmap.foliumap as leafmap

# Add raster datasets
crown = "tifs/zonal_clip.tif"
della = "tifs/della_clip.tif"
species = "tifs/spp_clip.tif"

# Initialize map and zoom to NV county
m = leafmap.Map(center=[39.12153746, -120.70667611], zoom=10)
m.add_basemap("CartoDB.Positron")

# Add layers to map
m.add_raster(della, colormap="viridis", layer_name="Old Growth", nodata=0)
m.add_raster(crown, colormap="rdylgn_r", layer_name="Crown Fire Probability", nodata=0)

# %%
# Define palettes
crown_colors = ["#1A9641", "#A6D96A", "#FFFFBF", "#FDAE61", "#D7191C"]
crown_vmin = 0
crown_vmax = 1

della_colors = ["#440154", "#31688E", "#35B779", "#FDE724"]
della_vmin = 3
della_vmax = 12

# Add colorbar and map. Click wrench and layers icon to toggle layers
m.add_colorbar(
    colors=della_colors, 
    vmin=della_vmin, 
    vmax=della_vmax, 
    caption="Old-Growth", 
    position="bottomright")
m.add_colorbar(
    colors=crown_colors, 
    vmin=crown_vmin, 
    vmax=crown_vmax,
    position="bottomright", 
    caption="Crown Fire Probability")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad283fbee48e143fe295c1b547d4554d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad283fbee48e143fe295c1b547d4554d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad283fbee48e143fe295c1b547d4554d = L.map(
#                 &quot;map_ad283fbee48e143fe295c1b547d4554d&quot;,
#                 {
#                     center: [39.12153746, -120.70667611],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#
#
#
#             var tile_layer_619179b45cebea2cb77356ca7040d29c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_619179b45cebea2cb77356ca7040d29c.addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#             map_ad283fbee48e143fe295c1b547d4554d.fitBounds(
#                 [[39.12153746, -120.70667611], [39.12153746, -120.70667611]],
#                 {&quot;maxZoom&quot;: 10}
#             );
#
#
#             var tile_layer_b74f5deb5cd4c11dcc6cf51b97fb298e = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b74f5deb5cd4c11dcc6cf51b97fb298e.addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#             var tile_layer_3fc9bd3dfece84284fdf3be1c5f5ed96 = L.tileLayer(
#                 &quot;http://127.0.0.1:40377/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fhome%2Fvauncer%2F2-areas%2Fpredicting_fire2%2Ftifs%2Fdella_clip.tif\u0026colormap=viridis\u0026nodata=0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
#   &quot;bounds&quot;: [[38.352281, -121.888967], [39.900197, -119.77495]],
#   &quot;corsAll&quot;: false,
# }
#
#             );
#
#
#             tile_layer_3fc9bd3dfece84284fdf3be1c5f5ed96.addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#             map_ad283fbee48e143fe295c1b547d4554d.fitBounds(
#                 [[38.352281, -121.888967], [39.900197, -119.77495]],
#                 {}
#             );
#
#
#             var tile_layer_643790951fdb0f25dfeeac088dc93621 = L.tileLayer(
#                 &quot;http://127.0.0.1:40377/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fhome%2Fvauncer%2F2-areas%2Fpredicting_fire2%2Ftifs%2Fzonal_clip.tif\u0026colormap=rdylgn_r\u0026nodata=0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
#   &quot;bounds&quot;: [[38.338524, -121.882664], [39.886116, -119.769214]],
#   &quot;corsAll&quot;: false,
# }
#
#             );
#
#
#             tile_layer_643790951fdb0f25dfeeac088dc93621.addTo(map_ad283fbee48e143fe295c1b547d4554d);
#
#
#             map_ad283fbee48e143fe295c1b547d4554d.fitBounds(
#                 [[38.338524, -121.882664], [39.886116, -119.769214]],
#                 {}
#             );
#
#
#     var color_map_bcf347f3bbc22b7bb

# %% [markdown]
# (della)=
# ## Old-growth
# In the map above, click on the layers icon in the upper right and click crown fire probablity on and off to compare layers.[^1]
#
# [^1]: Preliminary maps. I'm working on a swipe map and moving the colorbars to bottom right to make the visualization easier to interpret.

# %%
# Compare to listed species
# Create second map
m2 = leafmap.Map(center=[39.12153746, -120.70667611], zoom=10)
m2.add_basemap("CartoDB.Positron")
# Add layers to m2
m2.add_raster(species, colormap="reds", layer_name="Listed Species Richness", nodata=0)
m2.add_raster(crown, colormap="rdylgn_r", layer_name="Crown Fire Probability", nodata=0, show=False)

# Define palettes for m2
crown_colors = ["#1A9641", "#A6D96A", "#FFFFBF", "#FDAE61", "#D7191C"]
crown_vmin = 0
crown_vmax = 1

# Continuous reds for species
species_colors = ["#FFF5F0", "#FEE0D2", "#FCBBA1", "#FC9272", "#FB6A4A", "#EF3B2C", "#CB181D", "#A50F15", "#67000D"]
species_vmin = 0
species_vmax = 9

# Add colorbars to m2
m2.add_colorbar(
    colors=species_colors, 
    vmin=species_vmin, 
    vmax=species_vmax, 
    caption="Listed Species Richness")
m2.add_colorbar(
    colors=crown_colors, 
    vmin=crown_vmin, 
    vmax=crown_vmax, caption="Crown Fire Probability")
m2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b9d506cd149ee872528e798c799e7b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b9d506cd149ee872528e798c799e7b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b9d506cd149ee872528e798c799e7b1 = L.map(
#                 &quot;map_0b9d506cd149ee872528e798c799e7b1&quot;,
#                 {
#                     center: [39.12153746, -120.70667611],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0b9d506cd149ee872528e798c799e7b1);
#
#
#
#
#
#             var tile_layer_94900d9f8b0df8cd658cb85017193f93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94900d9f8b0df8cd658cb85017193f93.addTo(map_0b9d506cd149ee872528e798c799e7b1);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_0b9d506cd149ee872528e798c799e7b1);
#
#
#             map_0b9d506cd149ee872528e798c799e7b1.fitBounds(
#                 [[39.12153746, -120.70667611], [39.12153746, -120.70667611]],
#                 {&quot;maxZoom&quot;: 10}
#             );
#
#
#             var tile_layer_b74f5deb5cd4c11dcc6cf51b97fb298e = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b74f5deb5cd4c11dcc6cf51b97fb298e.addTo(map_0b9d506cd149ee872528e798c799e7b1);
#
#
#             var tile_layer_4dde8dfe466a7defa5ffb096f81be89d = L.tileLayer(
#                 &quot;http://127.0.0.1:40377/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fhome%2Fvauncer%2F2-areas%2Fpredicting_fire2%2Ftifs%2Fspp_clip.tif\u0026colormap=reds\u0026nodata=0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
#   &quot;bounds&quot;: [[38.3481, -121.891871], [39.900918, -119.772732]],
#   &quot;corsAll&quot;: false,
# }
#
#             );
#
#
#             tile_layer_4dde8dfe466a7defa5ffb096f81be89d.addTo(map_0b9d506cd149ee872528e798c799e7b1);
#
#
#             map_0b9d506cd149ee872528e798c799e7b1.fitBounds(
#                 [[38.3481, -121.891871], [39.900918, -119.772732]],
#                 {}
#             );
#
#
#             var tile_layer_d1564df2b078073cb0607cbac2f7977b = L.tileLayer(
#                 &quot;http://127.0.0.1:40377/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fhome%2Fvauncer%2F2-areas%2Fpredicting_fire2%2Ftifs%2Fzonal_clip.tif\u0026colormap=rdylgn_r\u0026nodata=0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
#   &quot;bounds&quot;: [[38.338524, -121.882664], [39.886116, -119.769214]],
#   &quot;corsAll&quot;: false,
# }
#
#             );
#
#
#             map_0b9d506cd149ee872528e798c799e7b1.fitBounds(
#                 [[38.338524, -121.882664], [39.886116, -119.769214]],
#                 {}
#             );
#
#
#     var color_map_715dfa8d77c506f51bc691a4af7d63be = {};
#
#
#     color_map_715dfa8d77c506f51bc691a4af7d63be.color = d3.scale.threshold()
#               .dom

# %% [markdown]
# (spp)=
# ## Species Richness
# In the map above, click on the layers icon in the upper right and click crown fire probablity on and off to compare layers.
